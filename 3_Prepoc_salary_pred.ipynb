# %% [markdown]
# # Preprocessing Data

# %% [markdown]
# Based on the insights we gathered from EDA we are going to prepare our data for machine learning

# %%
import sys
import pandas as pd
import joblib
from sklearn.preprocessing import OrdinalEncoder

# %%
sys.path.append ('./modules') #modules folder contains the helper file(a collection of written fuctions). see below

# %%
#The helper module contains functions created to process the data
from helper import cat_ord_enc, cat_feat_list, add_binned_feat

# %%
train_data = joblib.load( 'merged_part_cleaned_trainset') #loading cleaned train data set

# %% [markdown]
# Encoding categorical features based on average salaries as seen during EDA

# %%
cat_ord_enc(train_data, 'salary') #function ordinally encondes values in each feature
# Out:
#  Data encoded
#        companyId         jobType       degree      major   industry  \
# 0         COMP37             CFO      MASTERS       MATH     HEALTH
# 1         COMP19             CEO  HIGH_SCHOOL       NONE        WEB
# 2         COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS     HEALTH
# 3         COMP38         MANAGER     DOCTORAL  CHEMISTRY       AUTO
# 4          COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS    FINANCE
# ...          ...             ...          ...        ...        ...
# 999995    COMP56  VICE_PRESIDENT    BACHELORS  CHEMISTRY     HEALTH
# 999996    COMP24             CTO  HIGH_SCHOOL       NONE    FINANCE
# 999997    COMP23          JUNIOR  HIGH_SCHOOL       NONE  EDUCATION
# 999998     COMP3             CFO      MASTERS       NONE     HEALTH
# 999999    COMP59          JUNIOR    BACHELORS       NONE  EDUCATION
#
#         yearsExperience  milesFromMetropolis  salary  companyId_cat  \
# ...

# %% [markdown]
# Grouping yearExperience and milesFromMetropolis features into categories using insigths from EDA

# %%
add_binned_feat(train_data, 'yearsExperience', 6, [1,2,3,4,5,6], 'yearsExp_cat')
add_binned_feat(train_data, 'milesFromMetropolis', 10, [i for i in range(10,0,-1)], 'mfm_cat') #average salary inversly propotional to milesFromMetropolis
# Out:
# yearsExperience  values binned
# milesFromMetropolis  values binned
#        companyId         jobType       degree      major   industry  \
# 0         COMP37             CFO      MASTERS       MATH     HEALTH
# 1         COMP19             CEO  HIGH_SCHOOL       NONE        WEB
# 2         COMP52  VICE_PRESIDENT     DOCTORAL    PHYSICS     HEALTH
# 3         COMP38         MANAGER     DOCTORAL  CHEMISTRY       AUTO
# 4          COMP7  VICE_PRESIDENT    BACHELORS    PHYSICS    FINANCE
# ...          ...             ...          ...        ...        ...
# 999995    COMP56  VICE_PRESIDENT    BACHELORS  CHEMISTRY     HEALTH
# 999996    COMP24             CTO  HIGH_SCHOOL       NONE    FINANCE
# 999997    COMP23          JUNIOR  HIGH_SCHOOL       NONE  EDUCATION
# 999998     COMP3             CFO      MASTERS       NONE     HEALTH
# 999999    COMP59          JUNIOR    BACHELORS       NONE  EDUCATION
#
#         yearsExperience  milesFromMetropolis  salary  companyId_cat  \
# ...

# %%
joblib.dump(train_data, 'prepoc_train_data') #saving processed data for machine learning
# Out:
# ['prepoc_train_data']
